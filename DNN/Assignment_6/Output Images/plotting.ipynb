# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load two images
img1 = mpimg.imread('ig_after_softmax.png')
img2 = mpimg.imread("ig_before_softmax.png") 

# Plot the images side by side
plt.figure(figsize=(15, 20))

plt.subplot(1, 2, 1)
plt.imshow(img1)
# plt.title('6.1: IG After Softmax (Standard)')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img2)
# plt.title('6.2: IG Before Softmax')
plt.axis('off')

plt.tight_layout()
plt.show()
# ...existing code...
